# %%
import time
import csv

    
x="Hello In Reading Word"
    
y="To begin Enter 'Start'"
    
print('\t',x,'\n')
print('Typing ...')
time.sleep(2) 
print('\t',y,'\n')


type1=[]
  
with open('mydatast1.csv','r+') as D:
    e=csv.DictReader(D)
    for row in e:
        if row['type1'] not in type1:
             type1.append(row['type1'])
    #print(type1)
    print('\n')
    z=input()
    print('\n')
    if z.upper()=='START':
        print("Let's choose a Book\n")
        time.sleep(2)
        print('The Availabe Types Is :         \n')
        time.sleep(2)
        print(str(type1))
        time.sleep(1)
        s=input('What Type Do You Love ?')
        print('\n')
        for i in range(len(type1)):
            type1[i]=type1[i].upper()
        if s.upper() in type1:
            #print('The type is',s)
            print('The Availabe Books in this type is :')
            print('\n')
            n=[]
            ind=[]
            with open('mydatast1.csv','r+') as D:
                e=csv.DictReader(D)
                
                for row in e :
                    x=row['type1']
                    counter1=[]
                    l=[]
                    if x.upper()==s.upper():
                        n.append(row['name'])
                        
                        
                        ind.append(row['#'])
                for i in range(len(n)):
                    print(i+1,'-',n[i],end='')
                    counter1.append(i+1)
                    
                    print('\n')
                print('Which Book you would like ti  read ?')
                time.sleep(1)
                print('Please enter your choise number ^^ ')
                k=int(input())
                l.append(ind[k-1])
                #print(l)
                if k in counter1 :
                    print('Here you can find these informations about the Book :')
                    time.sleep(1)
                    print(1,'-',"The writer's names ")
                    time.sleep(1)
                    print(2,'-',"How many page the book contains ?")
                    time.sleep(1)
                    print(3,'-',"writer overview")
                    time.sleep(1)
                    print(4,'-','book overview')
                    time.sleep(1)
                    print(5,'-','link to download')
                    time.sleep(1)
                    print('What would you like ?')
                    j=int(input())
                    
                    with open('mydatast1.csv','r+') as D:
                        e=csv.DictReader(D)
                        
                        if j ==1  :
                            for row in e:
                                if row['#']==l:
                                    print(row['name'])
                        if j ==2 :
                            for row in e:
                                if row['#']==l:
                                    print(row['pages'])
                        if j ==3 :
                            for row in e:
                                if row['#']==l:
                                    print(row['writer overview'])
                        if j ==4 :
                            for row in e:
                                if row['#']==l:
                                    print(row['book overview'])
                        if j ==5 :
                            for row in e:
                                if row['#']==l:
                                    print(row['link to download'])
                        else:
                            print('error')
                            
        else:
            print('Not availabe')
# Out:
# 	 Hello In Reading Word
#
# Typing ...
# 	 To begin Enter 'Start'
#
#
#
# start
#
#
# Let's choose a Book
#
# The Availabe Types Is :
#
# ['Novel', 'Spy', 'Vegetarian.cookbook', 'Short.story', 'Economics', 'Self-Care', '']
# What Type Do You Love ?spy
#
#
# The Availabe Books in this type is :
#
#
# 1 - Stalin’s Englishman
#
# 2 - Intercept: The Secret History of Computers and Spies
#
# 3 - The Night Manager
#
# Which Book you would like ti  read ?
# Please enter your choise number ^^
# 2
# Here you can find these informations about the Book :
# 1 - The writer's names
# 2 - How many page the book contains ?
# 3 - writer overview
# 4 - book overview
# 5 - link to download
# What would you like ?
# 3
# error
